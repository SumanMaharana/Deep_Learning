# %% [markdown]
# ### Demonstrate RNN that learns to perform sequence analysis for stock price.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings("ignore")

# %%
training_data = pd.read_csv("/content/drive/MyDrive/dsai/SEM 3/DL/datasets/Google_Stock_Price_Train.csv")
training_data.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %%
training_data.shape
# Out:
# (1258, 6)

# %%
train_data = training_data.iloc[:,1:2].values
train_data
# Out:
# array([[325.25],
#        [331.27],
#        [329.83],
#        ...,
#        [793.7 ],
#        [783.33],
#        [782.75]])

# %%
sc = MinMaxScaler(feature_range=(0,1))

# %%
train_set_scaled = sc.fit_transform(train_data)
train_set_scaled
# Out:
# array([[0.08581368],
#        [0.09701243],
#        [0.09433366],
#        ...,
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %%
x_train=[]
y_train=[]

# %%
for i in range(60,1258):
  x_train.append(train_set_scaled[i-60:i, 0])
  y_train.append(train_set_scaled[i,0])

# %%
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
x_train
# Out:
# array([[0.08581368, 0.09701243, 0.09433366, ..., 0.07846566, 0.08034452,
#         0.08497656],
#        [0.09701243, 0.09433366, 0.09156187, ..., 0.08034452, 0.08497656,
#         0.08627874],
#        [0.09433366, 0.09156187, 0.07984225, ..., 0.08497656, 0.08627874,
#         0.08471612],
#        ...,
#        [0.92106928, 0.92438053, 0.93048218, ..., 0.95475854, 0.95204256,
#         0.95163331],
#        [0.92438053, 0.93048218, 0.9299055 , ..., 0.95204256, 0.95163331,
#         0.95725128],
#        [0.93048218, 0.9299055 , 0.93113327, ..., 0.95163331, 0.95725128,
#         0.93796041]])

# %%
y_train
# Out:
# array([0.08627874, 0.08471612, 0.07454052, ..., 0.95725128, 0.93796041,
#        0.93688146])

# %%
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1],1))
x_train
# Out:
# array([[[0.08581368],
#         [0.09701243],
#         [0.09433366],
#         ...,
#         [0.07846566],
#         [0.08034452],
#         [0.08497656]],
#
#        [[0.09701243],
#         [0.09433366],
#         [0.09156187],
#         ...,
#         [0.08034452],
#         [0.08497656],
#         [0.08627874]],
#
#        [[0.09433366],
#         [0.09156187],
#         [0.07984225],
#         ...,
#         [0.08497656],
#         [0.08627874],
#         [0.08471612]],
#
#        ...,
#
#        [[0.92106928],
#         [0.92438053],
#         [0.93048218],
#         ...,
#         [0.95475854],
#         [0.95204256],
#         [0.95163331]],
#
#        [[0.92438053],
#         [0.93048218],
#         [0.9299055 ],
#         ...,
#         [0.95204256],
#         [0.95163331],
#         [0.95725128]],
#
#        [[0.93048218],
#         [0.9299055 ],
#         [0.93113327],
#         ...,
#         [0.95163331],
#         [0.95725128],
#         [0.93796041]]])

# %%
regressor_stock = Sequential()

# %%
regressor_stock.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))

# %%
regressor_stock.add(Dropout(0.2))
regressor_stock.add(LSTM(units=50, return_sequences=True))

# %%
regressor_stock.add(Dropout(0.2))
regressor_stock.add(LSTM(units=50, return_sequences=True))

# %%
regressor_stock.add(Dropout(0.2))
regressor_stock.add(LSTM(units=50))

# %%
regressor_stock.add(Dropout(0.2))
regressor_stock.add(Dense(units=1))

# %%
regressor_stock.compile(optimizer="adam", loss="mean_absolute_error")
regressor_stock.fit(x_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 29s 163ms/step - loss: 0.1331
# Epoch 2/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0565
# Epoch 3/100
# 38/38 [==============================] - 7s 190ms/step - loss: 0.0544
# Epoch 4/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0529
# Epoch 5/100
# 38/38 [==============================] - 7s 182ms/step - loss: 0.0530
# Epoch 6/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0501
# Epoch 7/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0486
# Epoch 8/100
# 38/38 [==============================] - 7s 189ms/step - loss: 0.0496
# Epoch 9/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0466
# Epoch 10/100
# 38/38 [==============================] - 7s 195ms/step - loss: 0.0454
# Epoch 11/100
# 38/38 [==============================] - 5s 134ms/step - loss: 0.0482
# Epoch 12/100
# 38/38 [==============================] - 6s 153ms/step - loss: 0.0449
# Epoch 13/100
# 38/38 [==============================] - 7s 171ms/step - loss: 0.0417
# Epoch 14/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0471
# Epoch 15/100
# 38/38 [==============================] - 7s 190ms/step - loss: 0.0442
# Epoch 16/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0411
# Epoch 17/100
# 38/38 [==============================] - 7s 196ms/step - loss: 0.0404
# Epoch 18/100
# 38/38 [==============================] - 6s 144ms/step - loss: 0.0429
# Epoch 19/100
# 38/38 [==============================] - 5s 133ms/step - loss: 0.0414
# Epoch 20/100
# 38/38 [==============================] - 7s 190ms/step - loss: 0.0380
# Epoch 21/100
# 38/38 [==============================] - 6s 150ms/step - loss: 0.0420
# Epoch 22/100
# 38/38 [==============================] - 9s 232ms/step - loss: 0.0389
# Epoch 23/100
# 38/38 [==============================] - 6s 151ms/step - loss: 0.0417
# Epoch 24/100
# 38/38 [==============================] - 6s 163ms/step - loss: 0.0418
# Epoch 25/100
# 38/38 [==============================] - 6s 162ms/step - loss: 0.0377
# Epoch 26/100
# 38/38 [==============================] - 5s 134ms/step - loss: 0.0381
# Epoch 27/100
# 38/38 [==============================] - 7s 187ms/step - loss: 0.0400
# Epoch 28/100
# 38/38 [==============================] - 5s 141ms/step - loss: 0.0359
# Epoch 29/100
# 38/38 [==============================] - 7s 179ms/step - loss: 0.0366
# Epoch 30/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0385
# Epoch 31/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0366
# Epoch 32/100
# 38/38 [==============================] - 8s 204ms/step - loss: 0.0365
# Epoch 33/100
# 38/38 [==============================] - 5s 134ms/step - loss: 0.0374
# Epoch 34/100
# 38/38 [==============================] - 7s 188ms/step - loss: 0.0364
# Epoch 35/100
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0379
# Epoch 36/100
# 38/38 [==============================] - 6s 146ms/step - loss: 0.0366
# Epoch 37/100
# 38/38 [==============================] - 7s 173ms/step - loss: 0.0371
# Epoch 38/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0392
# Epoch 39/100
# 38/38 [==============================] - 7s 191ms/step - loss: 0.0346
# Epoch 40/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0338
# Epoch 41/100
# 38/38 [==============================] - 6s 156ms/step - loss: 0.0326
# Epoch 42/100
# 38/38 [==============================] - 6s 167ms/step - loss: 0.0363
# Epoch 43/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0344
# Epoch 44/100
# 38/38 [==============================] - 7s 188ms/step - loss: 0.0345
# Epoch 45/100
# 38/38 [==============================] - 5s 140ms/step - loss: 0.0328
# Epoch 46/100
# 38/38 [==============================] - 7s 175ms/step - loss: 0.0329
# Epoch 47/100
# 38/38 [==============================] - 6s 151ms/step - loss: 0.0334
# Epoch 48/100
# 38/38 [==============================] - 5s 144ms/step - loss: 0.0334
# Epoch 49/100
# 38/38 [==============================] - 7s 193ms/step - loss: 0.0361
# Epoch 50/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0330
# Epoch 51/100
# 38/38 [==============================] - 7s 193ms/step - loss: 0.0333
# Epoch 52/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0317
# Epoch 53/100
# 38/38 [==============================] - 6s 168ms/step - loss: 0.0337
# Epoch 54/100
# 38/38 [==============================] - 8s 215ms/step - loss: 0.0322
# Epoch 55/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0306
# Epoch 56/100
# 38/38 [==============================] - 7s 177ms/step - loss: 0.0308
# Epoch 57/100
# 38/38 [==============================] - 6s 153ms/step - loss: 0.0310
# Epoch 58/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0329
# Epoch 59/100
# 38/38 [==============================] - 7s 191ms/step - loss: 0.0315
# Epoch 60/100
# 38/38 [==============================] - 5s 143ms/step - loss: 0.0319
# Epoch 61/100
# 38/38 [==============================] - 7s 192ms/step - loss: 0.0297
# Epoch 62/100
# 38/38 [==============================] - 5s 138ms/step - loss: 0.0297
# Epoch 63/100
# 38/38 [==============================] - 6s 155ms/step - loss: 0.0307
# Epoch 64/100
# 38/38 [==============================] - 6s 167ms/step - loss: 0.0300
# Epoch 65/100
# 38/38 [==============================] - 5s 136ms/step - loss: 0.0322
# Epoch 66/100
# 38/38 [==============================] - 7s 189ms/step - loss: 0.0308
# Epoch 67/100
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0304
# Epoch 68/100
# 38/38 [==============================] - 6s 153ms/step - loss: 0.0297
# Epoch 69/100
# 38/38 [==============================] - 6s 166ms/step - loss: 0.0301
# Epoch 70/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0299
# Epoch 71/100
# 38/38 [==============================] - 7s 187ms/step - loss: 0.0286
# Epoch 72/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0291
# Epoch 73/100
# 38/38 [==============================] - 6s 168ms/step - loss: 0.0283
# Epoch 74/100
# 38/38 [==============================] - 6s 160ms/step - loss: 0.0283
# Epoch 75/100
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0282
# Epoch 76/100
# 38/38 [==============================] - 7s 188ms/step - loss: 0.0288
# Epoch 77/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0281
# Epoch 78/100
# 38/38 [==============================] - 7s 176ms/step - loss: 0.0288
# Epoch 79/100
# 38/38 [==============================] - 6s 145ms/step - loss: 0.0300
# Epoch 80/100
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0276
# Epoch 81/100
# 38/38 [==============================] - 7s 187ms/step - loss: 0.0287
# Epoch 82/100
# 38/38 [==============================] - 5s 133ms/step - loss: 0.0285
# Epoch 83/100
# 38/38 [==============================] - 7s 184ms/step - loss: 0.0287
# Epoch 84/100
# 38/38 [==============================] - 5s 139ms/step - loss: 0.0310
# Epoch 85/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0273
# Epoch 86/100
# 38/38 [==============================] - 10s 254ms/step - loss: 0.0272
# Epoch 87/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0280
# Epoch 88/100
# 38/38 [==============================] - 6s 147ms/step - loss: 0.0275
# Epoch 89/100
# 38/38 [==============================] - 7s 175ms/step - loss: 0.0277
# Epoch 90/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0285
# Epoch 91/100
# 38/38 [==============================] - 7s 190ms/step - loss: 0.0276
# Epoch 92/100
# 38/38 [==============================] - 5s 131ms/step - loss: 0.0266
# Epoch 93/100
# 38/38 [==============================] - 6s 156ms/step - loss: 0.0279
# Epoch 94/100
# 38/38 [==============================] - 6s 165ms/step - loss: 0.0252
# Epoch 95/100
# 38/38 [==============================] - 5s 137ms/step - loss: 0.0295
# Epoch 96/100
# 38/38 [==============================] - 7s 187ms/step - loss: 0.0296
# Epoch 97/100
# 38/38 [==============================] - 5s 135ms/step - loss: 0.0302
# Epoch 98/100
# 38/38 [==============================] - 6s 164ms/step - loss: 0.0262
# Epoch 99/100
# 38/38 [==============================] - 6s 157ms/step - loss: 0.0267
# Epoch 100/100
# 38/38 [==============================] - 5s 132ms/step - loss: 0.0263

# %%
testing_data = pd.read_csv("/content/drive/MyDrive/dsai/SEM 3/DL/datasets/Google_Stock_Price_Test.csv")
testing_data.head()
# Out:
#        Date    Open    High     Low   Close     Volume
# 0  1/3/2017  778.81  789.63  775.80  786.14  1,657,300
# 1  1/4/2017  788.36  791.34  783.16  786.90  1,073,000
# 2  1/5/2017  786.08  794.48  785.02  794.02  1,335,200
# 3  1/6/2017  795.26  807.90  792.20  806.15  1,640,200
# 4  1/9/2017  806.40  809.97  802.83  806.65  1,272,400

# %%
testing_data.shape
# Out:
# (20, 6)

# %%
real_stock_price = testing_data.iloc[:,1:2].values

# %%
dataset_total = pd.concat((training_data["Open"], testing_data["Open"]), axis=0)
dataset_total
# Out:
# 0     325.25
# 1     331.27
# 2     329.83
# 3     328.34
# 4     322.04
#        ...
# 15    829.62
# 16    837.81
# 17    834.71
# 18    814.66
# 19    796.86
# Name: Open, Length: 1278, dtype: float64

# %%
inputs = dataset_total[len(dataset_total) - len(testing_data) - 60:].values
inputs
# Out:
# array([779.  , 779.66, 777.71, 786.66, 783.76, 781.22, 781.65, 779.8 ,
#        787.85, 798.24, 803.3 , 795.  , 804.9 , 816.68, 806.34, 801.  ,
#        808.35, 795.47, 782.89, 778.2 , 767.25, 750.66, 774.5 , 783.4 ,
#        779.94, 791.17, 756.54, 755.6 , 746.97, 755.2 , 766.92, 771.37,
#        762.61, 772.63, 767.73, 764.26, 760.  , 771.53, 770.07, 757.44,
#        744.59, 757.71, 764.73, 761.  , 772.48, 780.  , 785.04, 793.9 ,
#        797.4 , 797.34, 800.4 , 790.22, 796.76, 795.84, 792.36, 790.9 ,
#        790.68, 793.7 , 783.33, 782.75, 778.81, 788.36, 786.08, 795.26,
#        806.4 , 807.86, 805.  , 807.14, 807.48, 807.08, 805.81, 805.12,
#        806.91, 807.25, 822.3 , 829.62, 837.81, 834.71, 814.66, 796.86])

# %%
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
inputs
# Out:
# array([[0.9299055 ],
#        [0.93113327],
#        [0.92750577],
#        [0.94415507],
#        [0.93876032],
#        [0.93403527],
#        [0.93483518],
#        [0.9313937 ],
#        [0.94636878],
#        [0.96569685],
#        [0.97510976],
#        [0.95966962],
#        [0.97808617],
#        [1.        ],
#        [0.98076494],
#        [0.97083116],
#        [0.98450406],
#        [0.96054394],
#        [0.9371419 ],
#        [0.92841729],
#        [0.90804747],
#        [0.8771858 ],
#        [0.92153434],
#        [0.93809063],
#        [0.93165414],
#        [0.95254483],
#        [0.88812412],
#        [0.88637547],
#        [0.87032145],
#        [0.88563137],
#        [0.90743359],
#        [0.91571173],
#        [0.89941588],
#        [0.91805566],
#        [0.9089404 ],
#        [0.9024853 ],
#        [0.89456061],
#        [0.91600938],
#        [0.9132934 ],
#        [0.88979835],
#        [0.86589404],
#        [0.89030062],
#        [0.90335962],
#        [0.89642086],
#        [0.91777662],
#        [0.93176576],
#        [0.94114145],
#        [0.95762334],
#        [0.96413424],
#        [0.96402262],
#        [0.96971501],
#        [0.95077759],
#        [0.96294367],
#        [0.96123223],
#        [0.95475854],
#        [0.95204256],
#        [0.95163331],
#        [0.95725128],
#        [0.93796041],
#        [0.93688146],
#        [0.92955205],
#        [0.94731751],
#        [0.94307612],
#        [0.96015329],
#        [0.98087655],
#        [0.98359253],
#        [0.97827219],
#        [0.98225314],
#        [0.98288563],
#        [0.98214153],
#        [0.979779  ],
#        [0.97849542],
#        [0.98182528],
#        [0.98245777],
#        [1.01045465],
#        [1.02407173],
#        [1.03930724],
#        [1.03354044],
#        [0.99624228],
#        [0.9631297 ]])

# %%
x_test = []
for i in range(60,80):
  x_test.append(inputs[i-60:i,0])

# %%
x_test = np.array(x_test)
x_test
# Out:
# array([[0.9299055 , 0.93113327, 0.92750577, ..., 0.95725128, 0.93796041,
#         0.93688146],
#        [0.93113327, 0.92750577, 0.94415507, ..., 0.93796041, 0.93688146,
#         0.92955205],
#        [0.92750577, 0.94415507, 0.93876032, ..., 0.93688146, 0.92955205,
#         0.94731751],
#        ...,
#        [0.96054394, 0.9371419 , 0.92841729, ..., 1.01045465, 1.02407173,
#         1.03930724],
#        [0.9371419 , 0.92841729, 0.90804747, ..., 1.02407173, 1.03930724,
#         1.03354044],
#        [0.92841729, 0.90804747, 0.8771858 , ..., 1.03930724, 1.03354044,
#         0.99624228]])

# %%
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))
x_test
# Out:
# array([[[0.9299055 ],
#         [0.93113327],
#         [0.92750577],
#         ...,
#         [0.95725128],
#         [0.93796041],
#         [0.93688146]],
#
#        [[0.93113327],
#         [0.92750577],
#         [0.94415507],
#         ...,
#         [0.93796041],
#         [0.93688146],
#         [0.92955205]],
#
#        [[0.92750577],
#         [0.94415507],
#         [0.93876032],
#         ...,
#         [0.93688146],
#         [0.92955205],
#         [0.94731751]],
#
#        ...,
#
#        [[0.96054394],
#         [0.9371419 ],
#         [0.92841729],
#         ...,
#         [1.01045465],
#         [1.02407173],
#         [1.03930724]],
#
#        [[0.9371419 ],
#         [0.92841729],
#         [0.90804747],
#         ...,
#         [1.02407173],
#         [1.03930724],
#         [1.03354044]],
#
#        [[0.92841729],
#         [0.90804747],
#         [0.8771858 ],
#         ...,
#         [1.03930724],
#         [1.03354044],
#         [0.99624228]]])

# %%
predicted_stock_price = regressor_stock.predict(x_test)
real_predictions = sc.inverse_transform(predicted_stock_price)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
plt.plot(real_stock_price, color="red", label="Real Price")
plt.plot(real_predictions, color="green", label="Predicted Price")
plt.legend()
